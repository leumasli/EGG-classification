# %%
## Importing the necessary packages
import numpy as np
import pandas as pd
import scipy.stats as scs
import re
from numpy import genfromtxt
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv1D, Conv2D,LSTM, BatchNormalization, MaxPooling1D, MaxPooling2D,Reshape
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from scipy import signal

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/Shareddrives/EE147
# Out:
# Mounted at /content/drive
# /content/drive/Shareddrives/EE147

# %% [markdown]
# ## Loading the dataset and creating the train, val and test sets

# %%
## Loading the dataset

## Loading the numpy arrays
dir = '/content/drive/Shareddrives/EE147/project_data/'
X_test = np.load(dir+"X_test.npy")
y_test = np.load(dir+"y_test.npy")
person_train_valid = np.load(dir+"person_train_valid.npy")
X_train_valid = np.load(dir+"X_train_valid.npy")
y_train_valid = np.load(dir+"y_train_valid.npy")
person_test = np.load(dir+"person_test.npy")

## Adjusting the labels so that 

# Cue onset left - 0
# Cue onset right - 1
# Cue onset foot - 2
# Cue onset tongue - 3

y_train_valid -= 769
y_test -= 769

print ('Training/Valid data shape: {}'.format(X_train_valid.shape))
print ('Test data shape: {}'.format(X_test.shape))
print ('Training/Valid target shape: {}'.format(y_train_valid.shape))
print ('Test target shape: {}'.format(y_test.shape))
print ('Person train/valid shape: {}'.format(person_train_valid.shape))
print ('Person test shape: {}'.format(person_test.shape))
# Out:
# Training/Valid data shape: (2115, 22, 1000)
# Test data shape: (443, 22, 1000)
# Training/Valid target shape: (2115,)
# Test target shape: (443,)
# Person train/valid shape: (2115, 1)
# Person test shape: (443, 1)

# %%
# random splitting
ind_valid = np.random.choice(2115, 500, replace=False)
ind_train = np.array(list(set(range(2115)).difference(set(ind_valid))))
(x_train, x_valid) = X_train_valid[ind_train], X_train_valid[ind_valid] 
(y_train, y_valid) = y_train_valid[ind_train], y_train_valid[ind_valid]

y_train = to_categorical(y_train, 4)
y_valid = to_categorical(y_valid, 4)

x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)

x_train = np.swapaxes(x_train, 1,3)
x_train = np.swapaxes(x_train, 1,2)
x_valid = np.swapaxes(x_valid, 1,3)
x_valid = np.swapaxes(x_valid, 1,2)

x_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)
x_test = np.swapaxes(x_test, 1,3)
x_test = np.swapaxes(x_test, 1,2)
y_test = to_categorical(y_test, 4)

print (x_train.shape)
print (y_train.shape)
print (x_test.shape)
print (y_test.shape)
print (x_valid.shape)
print (y_valid.shape)
# Out:
# (1615, 1000, 1, 22)
# (1615, 4)
# (443, 1000, 1, 22)
# (443, 4)
# (500, 1000, 1, 22)
# (500, 4)

# %% [markdown]
# # CNN-LSTM Model

# %%
# Model parameters
dropout = 0.5
learning_rate = 1e-3
epochs = 100

#Building the model

cnn_lstm_model = Sequential()

# First block of conv.
cnn_lstm_model.add(Conv2D(filters=25, kernel_size=(10,1), padding='same', activation='elu', input_shape=(1000,1,22)))
cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
cnn_lstm_model.add(BatchNormalization())
cnn_lstm_model.add(Dropout(dropout))

# Second block of conv.
cnn_lstm_model.add(Conv2D(filters=50, kernel_size=(10,1), padding='same', activation='elu'))
cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
cnn_lstm_model.add(BatchNormalization())
cnn_lstm_model.add(Dropout(dropout))

# Third block of conv.
cnn_lstm_model.add(Conv2D(filters=100, kernel_size=(10,1), padding='same', activation='elu'))
cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
cnn_lstm_model.add(BatchNormalization())
cnn_lstm_model.add(Dropout(dropout))

# FC+LSTM layer
cnn_lstm_model.add(Flatten())
cnn_lstm_model.add(Dense((50)))
cnn_lstm_model.add(Reshape((50,1)))
cnn_lstm_model.add(LSTM(10, dropout=0.5, recurrent_dropout=0.5, input_shape=(50,1), return_sequences=False))

# FC layer
cnn_lstm_model.add(Dense(4, activation='softmax'))

# Defining the optimizer
optimizer = keras.optimizers.Adam(lr=learning_rate)

# Compiling the model
cnn_lstm_model.compile(loss='categorical_crossentropy',
                 optimizer=optimizer,
                 metrics=['accuracy'])

# Printing the model summary
cnn_lstm_model.summary()

# Training and validating the model

cnn_lstm_results = cnn_lstm_model.fit(x_train,
             y_train,
             batch_size=64,
             epochs=epochs,
             validation_data=(x_valid, y_valid), verbose=True)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 1000, 1, 25)       5525
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 334, 1, 25)        0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 334, 1, 25)        100
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 334, 1, 25)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 334, 1, 50)        12550
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 112, 1, 50)        0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 112, 1, 50)        200
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 112, 1, 50)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 112, 1, 100)       50100
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 38, 1, 100)        0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 38, 1, 100)        400
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 38, 1, 100)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3800)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                190050
# _________________________________________________________________
# reshape (Reshape)            (None, 50, 1)             0
# _________________________________________________________________
# lstm (LSTM)                  (None, 10)                480
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 44
# =================================================================
# Total params: 259,449
# Trainable params: 259,099
# Non-trainable params: 350
# _________________________________________________________________
# Epoch 1/100
# 26/26 [==============================] - 7s 185ms/step - loss: 1.3933 - accuracy: 0.2256 - val_loss: 1.3956 - val_accuracy: 0.2200
# Epoch 2/100
# 26/26 [==============================] - 4s 163ms/step - loss: 1.3768 - accuracy: 0.2782 - val_loss: 1.3890 - val_accuracy: 0.2600
# Epoch 3/100
# 26/26 [==============================] - 4s 156ms/step - loss: 1.3667 - accuracy: 0.3179 - val_loss: 1.3641 - val_accuracy: 0.3000
# Epoch 4/100
# 26/26 [==============================] - 4s 157ms/step - loss: 1.3455 - accuracy: 0.3549 - val_loss: 1.3364 - val_accuracy: 0.3480
# Epoch 5/100
# 26/26 [==============================] - 5s 181ms/step - loss: 1.3202 - accuracy: 0.3786 - val_loss: 1.2996 - val_accuracy: 0.3880
# Epoch 6/100
# 26/26 [==============================] - 5s 179ms/step - loss: 1.2809 - accuracy: 0.4196 - val_loss: 1.2761 - val_accuracy: 0.4180
# Epoch 7/100
# 26/26 [==============================] - 5s 192ms/step - loss: 1.2601 - accuracy: 0.4406 - val_loss: 1.2845 - val_accuracy: 0.4160
# Epoch 8/100
# 26/26 [==============================] - 4s 170ms/step - loss: 1.2289 - accuracy: 0.4451 - val_loss: 1.2940 - val_accuracy: 0.4220
# Epoch 9/100
# 26/26 [==============================] - 4s 167ms/step - loss: 1.2277 - accuracy: 0.4599 - val_loss: 1.2891 - val_accuracy: 0.4260
# Epoch 10/100
# 26/26 [==============================] - 5s 185ms/step - loss: 1.1772 - accuracy: 0.4856 - val_loss: 1.2984 - val_accuracy: 0.4280
# Epoch 11/100
# 26/26 [==============================] - 4s 167ms/step - loss: 1.1608 - accuracy: 0.4961 - val_loss: 1.2432 - val_accuracy: 0.4580
# Epoch 12/100
# 26/26 [==============================] - 4s 160ms/step - loss: 1.1451 - accuracy: 0.5147 - val_loss: 1.3653 - val_accuracy: 0.3960
# Epoch 13/100
# 26/26 [==============================] - 4s 164ms/step - loss: 1.1650 - accuracy: 0.4765 - val_loss: 1.2690 - val_accuracy: 0.4480
# Epoch 14/100
# 26/26 [==============================] - 4s 158ms/step - loss: 1.1066 - accuracy: 0.5365 - val_loss: 1.3426 - val_accuracy: 0.4040
# Epoch 15/100
# 26/26 [==============================] - 4s 162ms/step - loss: 1.1236 - accuracy: 0.5212 - val_loss: 1.2511 - val_accuracy: 0.4540
# Epoch 16/100
# 26/26 [==============================] - 5s 178ms/step - loss: 1.0902 - accuracy: 0.5248 - val_loss: 1.2515 - val_accuracy: 0.4640
# Epoch 17/100
# 26/26 [==============================] - 4s 158ms/step - loss: 1.1080 - accuracy: 0.5241 - val_loss: 1.2235 - val_accuracy: 0.4880
# Epoch 18/100
# 26/26 [==============================] - 4s 151ms/step - loss: 1.0575 - accuracy: 0.5392 - val_loss: 1.2105 - val_accuracy: 0.4860
# Epoch 19/100
# 26/26 [==============================] - 4s 159ms/step - loss: 1.0842 - accuracy: 0.5297 - val_loss: 1.2171 - val_accuracy: 0.4880
# Epoch 20/100
# 26/26 [==============================] - 4s 153ms/step - loss: 1.0500 - accuracy: 0.5612 - val_loss: 1.2876 - val_accuracy: 0.4520
# Epoch 21/100
# 26/26 [==============================] - 4s 164ms/step - loss: 1.0382 - accuracy: 0.5710 - val_loss: 1.2274 - val_accuracy: 0.4760
# Epoch 22/100
# 26/26 [==============================] - 5s 178ms/step - loss: 1.0418 - accuracy: 0.5618 - val_loss: 1.2437 - val_accuracy: 0.4820
# Epoch 23/100
# 26/26 [==============================] - 4s 157ms/step - loss: 1.0215 - accuracy: 0.5710 - val_loss: 1.2886 - val_accuracy: 0.4560
# Epoch 24/100
# 26/26 [==============================] - 4s 158ms/step - loss: 1.0243 - accuracy: 0.5607 - val_loss: 1.3078 - val_accuracy: 0.4480
# Epoch 25/100
# 26/26 [==============================] - 4s 164ms/step - loss: 1.0083 - accuracy: 0.5690 - val_loss: 1.2557 - val_accuracy: 0.4740
# Epoch 26/100
# 26/26 [==============================] - 4s 152ms/step - loss: 1.0321 - accuracy: 0.5587 - val_loss: 1.2714 - val_accuracy: 0.4700
# Epoch 27/100
# 26/26 [==============================] - 4s 148ms/step - loss: 1.0062 - accuracy: 0.5768 - val_loss: 1.2410 - val_accuracy: 0.4820
# Epoch 28/100
# 26/26 [==============================] - 4s 149ms/step - loss: 0.9658 - accuracy: 0.5926 - val_loss: 1.2948 - val_accuracy: 0.4780
# Epoch 29/100
# 26/26 [==============================] - 4s 148ms/step - loss: 1.0038 - accuracy: 0.5937 - val_loss: 1.2744 - val_accuracy: 0.4680
# Epoch 30/100
# 26/26 [==============================] - 4s 154ms/step - loss: 0.9513 - accuracy: 0.5983 - val_loss: 1.2256 - val_accuracy: 0.4980
# Epoch 31/100
# 26/26 [==============================] - 4s 159ms/step - loss: 0.9494 - accuracy: 0.6168 - val_loss: 1.2125 - val_accuracy: 0.5180
# Epoch 32/100
# 26/26 [==============================] - 4s 153ms/step - loss: 0.9358 - accuracy: 0.6008 - val_loss: 1.2981 - val_accuracy: 0.4600
# Epoch 33/100
# 26/26 [==============================] - 4s 159ms/step - loss: 0.9265 - accuracy: 0.6262 - val_loss: 1.2191 - val_accuracy: 0.4940
# Epoch 34/100
# 26/26 [==============================] - 4s 155ms/step - loss: 0.9181 - accuracy: 0.5933 - val_loss: 1.2513 - val_accuracy: 0.4900
# Epoch 35/100
# 26/26 [==============================] - 4s 147ms/step - loss: 0.9322 - accuracy: 0.6203 - val_loss: 1.2817 - val_accuracy: 0.5000
# Epoch 36/100
# 26/26 [==============================] - 4s 144ms/step - loss: 0.9491 - accuracy: 0.6113 - val_loss: 1.2477 - val_accuracy: 0.5060
# Epoch 37/100
# 26/26 [==============================] - 4s 147ms/step - loss: 0.8838 - accuracy: 0.6331 - val_loss: 1.2413 - val_accuracy: 0.5100
# Epoch 38/100
# 26/26 [==============================] - 4s 136ms/step - loss: 0.8783 - accuracy: 0.6316 - val_loss: 1.2769 - val_accuracy: 0.4960
# Epoch 39/100
# 26/26 [==============================] - 4s 142ms/step - loss: 0.8779 - accuracy: 0.6515 - val_loss: 1.2275 - val_accuracy: 0.5300
# Epoch 40/100
# 26/26 [==============================] - 3s 135ms/step - loss: 0.8864 - accuracy: 0.6303 - val_loss: 1.2396 - val_accuracy: 0.5080
# Epoch 41/100
# 26/26 [==============================] - 4s 140ms/step - loss: 0.9212 - accuracy: 0.6033 - val_loss: 1.3222 - val_accuracy: 0.4740
# Epoch 42/100
# 26/26 [==============================] - 4s 172ms/step - loss: 0.8737 - accuracy: 0.6386 - val_loss: 1.3323 - val_accuracy: 0.4580
# Epoch 43/100
# 26/26 [==============================] - 4s 162ms/step - loss: 0.8526 - accuracy: 0.6598 - val_loss: 1.3263 - val_accuracy: 0.4820
# Epoch 44/100
# 26/26 [==============================] - 4s 156ms/step - loss: 0.8745 - accuracy: 0.6330 - val_loss: 1.2756 - val_accuracy: 0.5040
# Epoch 45/100
# 26/26 [==============================] - 4s 150ms/step - loss: 0.8892 - accuracy: 0.6191 - val_loss: 1.2517 - val_accuracy: 0.5100
# Epoch 46/100
# 26/26 [==============================] - 4s 159ms/step - loss: 0.8661 - accuracy: 0.6293 - val_loss: 1.2230 - val_accuracy: 0.5420
# Epoch 47/100
# 26/26 [==============================] - 4s 150ms/step - loss: 0.8046 - accuracy: 0.6762 - val_loss: 1.2667 - val_accuracy: 0.4980
# Epoch 48/100
# 26/26 [==============================] - 4s 144ms/step - loss: 0.8418 - accuracy: 0.6537 - val_loss: 1.2385 - val_accuracy: 0.5260
# Epoch 49/100
# 26/26 [==============================] - 4s 144ms/step - loss: 0.8313 - accuracy: 0.6564 - val_loss: 1.2554 - val_accuracy: 0.5260
# Epoch 50/100
# 26/26 [==============================] - 4s 144ms/step - loss: 0.7859 - accuracy: 0.6869 - val_loss: 1.3016 - val_accuracy: 0.5160
# Epoch 51/100
# 26/26 [==============================] - 4s 144ms/step - loss: 0.8200 - accuracy: 0.6579 - val_loss: 1.2436 - val_accuracy: 0.5360
# Epoch 52/100
# 26/26 [==============================] - 4s 144ms/step - loss: 0.7691 - accuracy: 0.6970 - val_loss: 1.3728 - val_accuracy: 0.4900
# Epoch 53/100
# 26/26 [==============================] - 4s 167ms/step - loss: 0.8100 - accuracy: 0.6813 - val_loss: 1.3462 - val_accuracy: 0.4900
# Epoch 54/100
# 26/26 [==============================] - 4s 144ms/step - loss: 0.8060 - accuracy: 0.6494 - val_loss: 1.3550 - val_accuracy: 0.5120
# Epoch 55/100
# 26/26 [==============================] - 4s 148ms/step - loss: 0.8006 - accuracy: 0.6646 - val_loss: 1.2783 - val_accuracy: 0.5100
# Epoch 56/100
# 26/26 [==============================] - 4s 151ms/step - loss: 0.7645 - accuracy: 0.6903 - val_loss: 1.3120 - val_accuracy: 0.5180
# Epoch 57/100
# 26/26 [==============================] - 4s 147ms/step - loss: 0.7680 - accuracy: 0.6902 - val_loss: 1.2872 - val_accuracy: 0.5120
# Epoch 58/100
# 26/26 [==============================] - 4s 148ms/step - loss: 0.7929 - accuracy: 0.6853 - val_loss: 1.3714 - val_accuracy: 0.5060
# Epoch 59/100
# 26/26 [==============================] - 4s 149ms/step - loss: 0.7805 - accuracy: 0.6933 - val_loss: 1.3324 - val_accuracy: 0.5180
# Epoch 60/100
# 26/26 [==============================] - 4s 153ms/step - loss: 0.7490 - accuracy: 0.6993 - val_loss: 1.3509 - val_accuracy: 0.5160
# Epoch 61/100
# 26/26 [==============================] - 4s 161ms/step - loss: 0.6976 - accuracy: 0.7294 - val_loss: 1.4266 - val_accuracy: 0.4940
# Epoch 62/100
# 26/26 [==============================] - 4s 158ms/step - loss: 0.7396 - accuracy: 0.6952 - val_loss: 1.3347 - val_accuracy: 0.5260
# Epoch 63/100
# 26/26 [==============================] - 4s 156ms/step - loss: 0.7914 - accuracy: 0.6702 - val_loss: 1.3345 - val_accuracy: 0.5160
# Epoch 64/100
# 26/26 [==============================] - 4s 163ms/step - loss: 0.7468 - accuracy: 0.7088 - val_loss: 1.4107 - val_accuracy: 0.4940
# Epoch 65/100
# 26/26 [==============================] - 4s 166ms/step - loss: 0.7532 - accuracy: 0.6868 - val_loss: 1.3392 - val_accuracy: 0.5340
# Epoch 66/100
# 26/26 [==============================] - 4s 160ms/step - loss: 0.7173 - accuracy: 0.7167 - val_loss: 1.3349 - val_accuracy: 0.5100
# Epoch 67/100
# 26/26 [==============================] - 4s 155ms/step - loss: 0.6777 - accuracy: 0.7374 - val_loss: 1.3007 - val_accuracy: 0.5340
# Epoch 68/100
# 26/26 [==============================] - 4s 159ms/step - loss: 0.6761 - accuracy: 0.7399 - val_loss: 1.3212 - val_accuracy: 0.5300
# Epoch 69/100
# 26/26 [==============================] - 4s 155ms/step - loss: 0.6998 - accuracy: 0.7274 - val_loss: 1.3321 - val_accuracy: 0.5420
# Epoch 70/100
# 26/26 [==============================] - 4s 154ms/step - loss: 0.7680 - accuracy: 0.6837 - val_loss: 1.5116 - val_accuracy: 0.4840
# Epoch 71/100
# 26/26 [==============================] - 4s 163ms/step - loss: 0.7059 - accuracy: 0.7239 - val_loss: 1.3601 - val_accuracy: 0.5200
# Epoch 72/100
# 26/26 [==============================] - 4s 164ms/step - loss: 0.7167 - accuracy: 0.7278 - val_loss: 1.2930 - val_accuracy: 0.5520
# Epoch 73/100
# 26/26 [==============================] - 4s 161ms/step - loss: 0.6677 - accuracy: 0.7466 - val_loss: 1.3608 - val_accuracy: 0.5400
# Epoch 74/100
# 26/26 [==============================] - 4s 166ms/step - loss: 0.6905 - accuracy: 0.7234 - val_loss: 1.3073 - val_accuracy: 0.5460
# Epoch 75/100
# 26/26 [==============================] - 4s 172ms/step - loss: 0.6743 - accuracy: 0.7332 - val_loss: 1.4347 - val_accuracy: 0.5260
# Epoch 76/100
# 26/26 [==============================] - 4s 154ms/step - loss: 0.6902 - accuracy: 0.7315 - val_loss: 1.3506 - val_accuracy: 0.5360
# Epoch 77/100
# 26/26 [==============================] - 4s 158ms/step - loss: 0.6621 - accuracy: 0.7581 - val_loss: 1.3056 - val_accuracy: 0.5280
# Epoch 78/100
# 26/26 [==============================] - 4s 155ms/step - loss: 0.6428 - accuracy: 0.7398 - val_loss: 1.3097 - val_accuracy: 0.5380
# Epoch 79/100
# 26/26 [==============================] - 4s 151ms/step - loss: 0.6430 - accuracy: 0.7486 - val_loss: 1.3876 - val_accuracy: 0.5400
# Epoch 80/100
# 26/26 [==============================] - 4s 151ms/step - loss: 0.6282 - accuracy: 0.7518 - val_loss: 1.3787 - val_accuracy: 0.5520
# Epoch 81/100
# 26/26 [==============================] - 4s 152ms/step - loss: 0.6396 - accuracy: 0.7496 - val_loss: 1.3774 - val_accuracy: 0.5300
# Epoch 82/100
# 26/26 [==============================] - 4s 155ms/step - loss: 0.6268 - accuracy: 0.7754 - val_loss: 1.3448 - val_accuracy: 0.5400
# Epoch 83/100
# 26/26 [==============================] - 4s 155ms/step - loss: 0.6203 - accuracy: 0.7541 - val_loss: 1.3546 - val_accuracy: 0.5280
# Epoch 84/100
# 26/26 [==============================] - 4s 160ms/step - loss: 0.6757 - accuracy: 0.7381 - val_loss: 1.4399 - val_accuracy: 0.5160
# Epoch 85/100
# 26/26 [==============================] - 4s 154ms/step - loss: 0.6229 - accuracy: 0.7820 - val_loss: 1.5201 - val_accuracy: 0.4980
# Epoch 86/100
# 26/26 [==============================] - 4s 160ms/step - loss: 0.6280 - accuracy: 0.7642 - val_loss: 1.3913 - val_accuracy: 0.5460
# Epoch 87/100
# 26/26 [==============================] - 4s 166ms/step - loss: 0.6803 - accuracy: 0.7291 - val_loss: 1.4238 - val_accuracy: 0.5140
# Epoch 88/100
# 26/26 [==============================] - 4s 160ms/step - loss: 0.6448 - accuracy: 0.7585 - val_loss: 1.3483 - val_accuracy: 0.5420
# Epoch 89/100
# 26/26 [==============================] - 4s 165ms/step - loss: 0.6381 - accuracy: 0.7469 - val_loss: 1.4031 - val_accuracy: 0.5280
# Epoch 90/100
# 26/26 [==============================] - 4s 165ms/step - loss: 0.6156 - accuracy: 0.7679 - val_loss: 1.3763 - val_accuracy: 0.5640
# Epoch 91/100
# 26/26 [==============================] - 4s 164ms/step - loss: 0.6442 - accuracy: 0.7581 - val_loss: 1.4039 - val_accuracy: 0.5620
# Epoch 92/100
# 26/26 [==============================] - 4s 149ms/step - loss: 0.5944 - accuracy: 0.7573 - val_loss: 1.4083 - val_accuracy: 0.5400
# Epoch 93/100
# 26/26 [==============================] - 4s 160ms/step - loss: 0.5668 - accuracy: 0.7787 - val_loss: 1.4672 - val_accuracy: 0.5260
# Epoch 94/100
# 26/26 [==============================] - 4s 150ms/step - loss: 0.5974 - accuracy: 0.7646 - val_loss: 1.4417 - val_accuracy: 0.5200
# Epoch 95/100
# 26/26 [==============================] - 4s 151ms/step - loss: 0.6035 - accuracy: 0.7876 - val_loss: 1.4714 - val_accuracy: 0.5200
# Epoch 96/100
# 26/26 [==============================] - 4s 155ms/step - loss: 0.6071 - accuracy: 0.7661 - val_loss: 1.4341 - val_accuracy: 0.5400
# Epoch 97/100
# 26/26 [==============================] - 4s 151ms/step - loss: 0.5861 - accuracy: 0.7704 - val_loss: 1.3590 - val_accuracy: 0.5440
# Epoch 98/100
# 26/26 [==============================] - 4s 155ms/step - loss: 0.5464 - accuracy: 0.8036 - val_loss: 1.4238 - val_accuracy: 0.5200
# Epoch 99/100
# 26/26 [==============================] - 4s 163ms/step - loss: 0.5647 - accuracy: 0.7891 - val_loss: 1.4846 - val_accuracy: 0.5400
# Epoch 100/100
# 26/26 [==============================] - 5s 178ms/step - loss: 0.5809 - accuracy: 0.7807 - val_loss: 1.5340 - val_accuracy: 0.5060

# %%
import matplotlib.pyplot as plt

# list all data in history
#print(history.history.keys())

# summarize history for accuracy
plt.plot(cnn_lstm_results.history['accuracy'])
plt.plot(cnn_lstm_results.history['val_accuracy'])
plt.title('CNN-LSTM model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(cnn_lstm_results.history['loss'],'o')
plt.plot(cnn_lstm_results.history['val_loss'],'o')
plt.title('CNN-LSTM model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
## Testing the CNN-LSTM model

score = cnn_lstm_model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the CNN-LSTM model:',score[1])
# Out:
# Test accuracy of the CNN-LSTM model: 0.544018030166626
